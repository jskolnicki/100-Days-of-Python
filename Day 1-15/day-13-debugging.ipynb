# %%
#Take breaks, run the code often, ask a friend.
#understand the problem, figure out your assumptions that might be false.

# %%
#practice debugging the leap year code

year = int(input("Which year do you want to check?"))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("Leap year.")
        else:
            print("Not leap year.")
    else:
        print("Leap year.")
else:
    print("Not leap year.")
# Out:
# Which year do you want to check?f
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7636/1630817500.py in <module>
#       1 #practice debugging the leap year code
#       2
# ----> 3 year = int(input("Which year do you want to check?"))
#       4
#       5 if year % 4 == 0:
#
# ValueError: invalid literal for int() with base 10: 'f'

# %%
# Your program should print each number from 1 to 100 in turn.

# When the number is divisible by 3 then instead of printing the number it should print "Fizz".

# When the number is divisible by 5, then instead of printing the number it should print "Buzz".` 

# And if the number is divisible by both 3 and 5 e.g. 15 then instead of the number it should print "FizzBuzz"

for number, num in zip(range(1, 101),range(1,101)):
    if number % 3 == 0 and number % 5 == 0:
        print("FizzBuzz", num)
    elif number % 3 == 0:
        print("Fizz", num)
    elif number % 5 == 0:
        print("Buzz", num)
    else:
        print(number, num)
# Out:
# 1 1
# 2 2
# Fizz 3
# 4 4
# Buzz 5
# Fizz 6
# 7 7
# 8 8
# Fizz 9
# Buzz 10
# 11 11
# Fizz 12
# 13 13
# 14 14
# FizzBuzz 15
# 16 16
# 17 17
# Fizz 18
# 19 19
# Buzz 20
# Fizz 21
# 22 22
# 23 23
# Fizz 24
# Buzz 25
# 26 26
# Fizz 27
# 28 28
# 29 29
# FizzBuzz 30
# 31 31
# 32 32
# Fizz 33
# 34 34
# Buzz 35
# Fizz 36
# 37 37
# 38 38
# Fizz 39
# Buzz 40
# 41 41
# Fizz 42
# 43 43
# 44 44
# FizzBuzz 45
# 46 46
# 47 47
# Fizz 48
# 49 49
# Buzz 50
# Fizz 51
# 52 52
# 53 53
# Fizz 54
# Buzz 55
# 56 56
# Fizz 57
# 58 58
# 59 59
# FizzBuzz 60
# 61 61
# 62 62
# Fizz 63
# 64 64
# Buzz 65
# Fizz 66
# 67 67
# 68 68
# Fizz 69
# Buzz 70
# 71 71
# Fizz 72
# 73 73
# 74 74
# FizzBuzz 75
# 76 76
# 77 77
# Fizz 78
# 79 79
# Buzz 80
# Fizz 81
# 82 82
# 83 83
# Fizz 84
# Buzz 85
# 86 86
# Fizz 87
# 88 88
# 89 89
# FizzBuzz 90
# 91 91
# 92 92
# Fizz 93
# 94 94
# Buzz 95
# Fizz 96
# 97 97
# 98 98
# Fizz 99
# Buzz 100
