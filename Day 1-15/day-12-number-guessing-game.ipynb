# %%
import random
logo = """

$$\   $$\$$\                 $$\                     $$\$$\$$\ 
$$ |  $$ \__|                $$ |                    $$ $$ $$ |
$$ |  $$ $$\                 $$ |     $$$$$$\        $$ $$ $$ |
$$$$$$$$ $$ |    $$$$$$\     $$ |    $$  __$$\       $$ $$ $$ |
$$  __$$ $$ |    \______|    $$ |    $$ /  $$ |      \__\__\__|
$$ |  $$ $$ |                $$ |    $$ |  $$ |                
$$ |  $$ $$ |                $$$$$$$$\$$$$$$  |      $$\$$\$$\ 
\__|  \__\__|                \________\______/       \__\__\__|
                                                                                                                   
                                                                                                    
"""

print(logo)

difficulty = input("Welcome to the Game!\nChoose your level of difficulty. 'Easy' or 'Hard' : ").lower()

print("I'm thinking of a number between 1 and 100.")

if difficulty == 'easy':
    guesses_remaining = 10
elif difficulty == 'hard':
    guesses_remaining = 5
else:
    print("You have entered an invalid difficulty.")
    sys.exit(0)
    
number_to_guess = random.randint(1,100)
correct_guess = False

while correct_guess == False:
    print(f"You have {guesses_remaining} guesses remaining.")
    guess = int(input("\nWhat is your guess? "))
    if guess == number_to_guess:
        print(f"You guessed correctly! The number was {number_to_guess}.")
        break
    elif guess > number_to_guess:
        print("Lower\n")
    elif guess < number_to_guess:
        print("Higher\n")
    guesses_remaining -= 1
    if guesses_remaining == 0:
        print("You have ran out of guesses. Better luck next time!")
        break
# Out:
# $$\   $$\$$\                 $$\                     $$\$$\$$\
# $$ |  $$ \__|                $$ |                    $$ $$ $$ |
# $$ |  $$ $$\                 $$ |     $$$$$$\        $$ $$ $$ |
# $$$$$$$$ $$ |    $$$$$$\     $$ |    $$  __$$\       $$ $$ $$ |
# $$  __$$ $$ |    \______|    $$ |    $$ /  $$ |      \__\__\__|
# $$ |  $$ $$ |                $$ |    $$ |  $$ |
# $$ |  $$ $$ |                $$$$$$$$\$$$$$$  |      $$\$$\$$\
# \__|  \__\__|                \________\______/       \__\__\__|
#
#
#
# Welcome to the Game!
# Choose your level of difficulty. 'Easy' or 'Hard' : easy
# I'm thinking of a number between 1 and 100.
# You have 10 guesses remaining.
#
# What is your guess? 1
# Higher
#
# You have 9 guesses remaining.
#
# What is your guess? 2
# Higher
#
# You have 8 guesses remaining.
#
# What is your guess? 3
# Higher
#
# You have 7 guesses remaining.
#
# What is your guess? 4
# Higher
#
# You have 6 guesses remaining.
#
# What is your guess? 5
# Higher
#
# ...
